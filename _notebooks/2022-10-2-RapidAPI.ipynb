// %% [markdown]
// # Rapid APIs
// - toc: true
// - badges: true
// - comments: true
// - categories: [jupyter]

// %%
import java.net.URI;
import java.net.http.HttpClient;
import java.net.http.HttpRequest;
import java.net.http.HttpResponse;

HttpRequest request = HttpRequest.newBuilder()
		.uri(URI.create("https://football-betting-odds1.p.rapidapi.com/provider1/live/upcoming"))
		.header("X-RapidAPI-Key", "6d22a6d34dmsh85d3aa4b9f888dbp153477jsn8417535364bf")
		.header("X-RapidAPI-Host", "football-betting-odds1.p.rapidapi.com")
		.method("GET", HttpRequest.BodyPublishers.noBody())
		.build();
HttpResponse<String> response = HttpClient.newHttpClient().send(request, HttpResponse.BodyHandlers.ofString());
System.out.println(response.body());
// Out:
// {"310131116190681":{"mid":"310131116190681","home":"Hapoel Petah Tikva FC","away":"Ironi Tiberias","country_leagues":"Israel - National League","leagues":"National League","country":"Israel","score":"0-0","home_score":0,"away_score":0,"periodID":"","periodTXT":"","periodTime":1664757460,"startTime":1664812800,"lastUpdateTime":1664757312,"minutes":0,"status":"1","importancy":65,"odds":{"home":"1.98","draw":"2.87","away":"3.70","1st-1":"2.75","1st-0":"1.88","1st-2":"4.50","2nd-1":"2.40","2nd-0":"2.20","2nd-2":"4.00","both-team-score-yes":"1.95","both-team-score-no":"1.66","double-chance-1-0":"1.24","double-chance-0-2":"1.72","double-chance-1-2":"1.36","draw-refund-1":"1.41","draw-refund-2":"2.70","total-goal-0":"5.63","total-goal-1":"3.38","total-goal-2":"2.97","total-goal-3":"3.96","total-goal-4":"6.30","total-goal-5":"11.70","total-goal-0-1":"2.25","total-goal-2-3":"1.80","total-goal-4+":"3.90","total-goal-0-2":"1.52","total-goal-3-4":"2.61","total-goal-5+":"8.10","total-goal-0-3":"
// ...
